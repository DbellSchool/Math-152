# %%
# Lab 3 

#TA : Alex

# Leilani Wilkinson, David Bell, Harrison LaCroix, Xavier Flores
# http://calclab.math.tamu.edu/Python/LabSched152.html

import matplotlib.pyplot as plt
from scipy.integrate import simps 
from numpy import * 
import sympy as sp

# %%
# Part 1
#A
x,y = sp.symbols('x y')
f = (sp.exp(x/2))/(x**3)
a = 1
b = 5
g = sp.plot(f,(x,a,b))

#B
sp.integrate(f,(x,a,b))
dx = (b-a)/100
x_i = arange(a,b,dx) #list of values from [a,b)
y_i = (sp.E**(x_i/2))/(x_i**3) #computes y values from list
L100 = sum(y_i)*dx
print("The Left Endpoint is",L100)
# Out:
# The Left Endpoint is 1.24278286691589

# %%
#Part 2
x_i = (arange(a+dx,b+dx,dx))
y_i = (sp.E**(x_i/2))/(x_i**3)
R100 = sum(y_i)*dx
print("The Right Endpoint approximation is",R100)
# Out:
# The Right Endpoint approximation is 1.18073241415531

# %%
#Part 3
#A
x_i = (arange(a,b+dx,dx))
y_i = (sp.E**(x_i/2))/(x_i**3)
M100 = sum(y_i)*dx
print("The Midpoint approximation is",M100)
print()

#Part B
avg = (L100+R100)/2
print("The average of the Left and Right Endpoint approximations,",avg,", are close but not equal to the Midpoint approximation")
# Out:
# The Midpoint approximation is 1.24668126498331
#
# The average of the Left and Right Endpoint approximations, 1.21175764053560 , are close but not equal to the Midpoint approximation

# %%
#Part 4
from scipy.integrate import trapz 
# Part A
x=sp.symbols('x')
dx=(5-1)/100


x_t=arange(1,5+dx,dx) 
y_t=sp.E**(x_t/2)/x_t**3
Trap_Aprox=trapz(y_t,x=x_t,dx=dx)
print("the value of the tepazoidal aproximation is",Trap_Aprox)


# Part B
x_l=arange(1,5,dx) # 
y_l=sp.E**(x_l/2)/x_l**3
left_Aprox = sum(y_l)*dx

x_r=arange(1+dx,5+dx,dx) 
y_r=sp.E**(x_r/2)/x_r**3
right_Aprox = sum(y_r)*dx


aprox = (left_Aprox+right_Aprox)/2
print("the rigt Aproxiamtion is:",right_Aprox)
print("the left Aproxiamtion is:",left_Aprox)
print("the average aproximation is:", aprox)
print("the diffrence between left and right aproximation is\n",abs(aprox-Trap_Aprox),"\nSo they is equal")



# Part C

x=sp.symbols("x") 
f=sp.exp(x/2)/x**3 
sp.plot(f,(x,1,5)) 
xp=[1,2,3,4,5] 
yp=[f.subs({x:i}) for i in xp] 

# imports 
import matplotlib.pyplot as plt
plt.plot(xp,yp)
# Out:
# the value of the tepazoidal aproximation is 1.21175764053560
# the rigt Aproxiamtion is: 1.18073241415531
# the left Aproxiamtion is: 1.24278286691589
# the average aproximation is: 1.21175764053560
# the diffrence between left and right aproximation is
#  0
# So they is equal

# %%
#Part 5

x=sp.symbols('x')
dx=(5-1)/100
 
#B

real = 1.2112096245

x_i = arange(a,b+dx,dx)
y_i = (sp.E**(x_i/2))/(x_i**3)
S100 = simps(y_i,x_i)
print("The Simpson's Approximation is",S100)
print()

#Part B
real = 1.2112096245
Lerr = real-right_Aprox
Rerr = real-left_Aprox
Merr = real-M100
Terr = real-Trap_Aprox
Serr = real-S100
print("The left endpoint error is",abs(Lerr))
print("The right endpoint error is",abs(Rerr))
print("The midpoint sum error is",abs(Merr))
print("The trapezoidal rule error is",abs(Terr))
print("The Simpson's Method error is",abs(Serr))
# Out:
# The Simpson's Approximation is 1.21121065128460
#
# The left endpoint error is 0.0304772103446904
# The right endpoint error is 0.0315732424158897
# The midpoint sum error is 0.0354716404833146
# The trapezoidal rule error is 0.000548016035599730
# The Simpson's Method error is 1.02678460200956e-6

# %%
#END
