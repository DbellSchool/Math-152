# %%
# Math 152
# Lab 1 

#TA : Alex

#David Bell

# http://calclab.math.tamu.edu/Python/LabSched152.html
from sympy import *
#from math import exp, sin, pi
from sympy.plotting import (plot, plot_parametric,plot3d_parametric_surface, plot3d_parametric_line,plot3d)
#Part 1
#A
x=symbols('x')
u=x^2+1
f = ((x**2+1)**(.5))*x**3
print("\nA\n")
print('u= x^2+1')
Fu = "1/2 * u**(3/2)-u^(1/2)"
print(Fu)
print("The intigral is : 1/2 * (2/5 * u**(5/2)- 2/3*u^(3/2))")

print("\nB\n")
#B
F=integrate(f,x)
print(f, "\n",F)

print("\nC/D\n")
#C
#do by hand ++Evaluate

#D
ans=integrate(f,(x,-1,10)) # finds area using pyhton 
ans1 = F.subs(x,10)-F.subs(x,-1)
print("the exact answer is :",ans1) # prints answer
print("the aproximent answer is:", ans.evalf()) # evaluates expresstion (uses sympy)

#D
#print("\nD\n")
## ?????
#f_int = Integral( f,(x,-1,10))
#f_int
# Out:
# A
#
# u= x^2+1
# 1/2 * u**(3/2)-u^(1/2)
# The intigral is : 1/2 * (2/5 * u**(5/2)- 2/3*u^(3/2))
#
# B
#
# x**3*(x**2 + 1)**0.5
#  0.333333333333333*x**2*(x**2 + 1)**1.5 - 0.133333333333333*(x**2 + 1)**2.5
#
# C/D
#
# the exact answer is : 20165.2218678248
# the aproximent answer is: 20165.2218678248

# %%
#Part 2
x=symbols('x')
f1 = 2*x*exp(x)
f2 = exp(pow(x,.5))
f3 = exp(sin(x))*sin(2*x)
#A
print("\nA\n")
G  =  plot(f1,(x,0,1), show = False)
G1 =  plot(f2,(x,0,1),show = False)
G2 =  plot(f3,(x,0,pi/2),show = False)
G.append(G1[0])
G.append(G2[0])
G.show()
#B
print("\nB\n")
f1_ans = integrate(f1,(x,0,1)) # finds area using pyhton 
f2_ans = integrate(f2,(x,0,1)) # finds area using pyhton 
f3_ans = integrate(f3,(x,0,pi/2)) # finds area using pyhton

num    = [f1_ans,f2_ans,f3_ans] # formatts information

print("the apraxamit answers is:",num)
#C
print("\nC\n")
t = expand_trig(f3)
f3_U = 2*x*exp(x)
#for ("f2")


print ("for f2  u = x^(1/2)")
print("f2 expanded is : 2*u*exp(u)")

print()

print ("for f3  u = sin(x)")
print("f3 expanded is : 2*u*exp(u)")


f1_ans = integrate(f1,(x,0,1)) # finds area using pyhton 
f2_ans = integrate(f2,(x,0,1)) # finds area using pyhton 
f3_ans = integrate(f3_U,(x,0,1)) # finds area using pyhton
num    = [f1_ans,f2_ans,f3_ans] # formatts information
#print(num)
#print()
# Out:
# A
# B
#
# the apraxamit answers is: [2, 2.00000000000000, 2]
#
# C
#
# for f2  u = x^(1/2)
# f2 expanded is : 2*u*exp(u)
#
# for f3  u = sin(x)
# f3 expanded is : 2*u*exp(u)

# %%
#Part 3
f = pow(x,5)-6*pow(x,3)+4*x
g = x
#A
print("\nA\n")
G  =  plot(f,x,ylim = (-10,10), show = False)
G1 =  plot(g,show = False)
G.append(G1[0])
G.show()
ans_act = solve(f-g,x)
ans_aprox  = [i.evalf() for i in ans_act]
#ans = ans.sort()
print("all intersections are: " , ans_aprox)

#B
print("\nB\n")
print("these are the points of intersections",ans_act)
fint_act = Integral( abs(g-f),(x,ans_act[-2],ans_act[-1]))
fint_aprox = Integral( abs(g-f),(x,ans_aprox[-2],ans_aprox[-1])).evalf()
print("the actual integral is:",fint_act)
print("the aaproxamant intigral is:",fint_aprox)
# Out:
# A
# all intersections are:  [0, -0.741963784302726, 0.741963784302726, -2.33441421833898, 2.33441421833898]
#
# B
#
# these are the points of intersections [0, -sqrt(3 - sqrt(6)), sqrt(3 - sqrt(6)), -sqrt(sqrt(6) + 3), sqrt(sqrt(6) + 3)]
# the actual integral is: Integral(Abs(x**5 - 6*x**3 + 3*x), (x, -sqrt(sqrt(6) + 3), sqrt(sqrt(6) + 3)))
# the aaproxamant intigral is: 20.4

# %%
#END
